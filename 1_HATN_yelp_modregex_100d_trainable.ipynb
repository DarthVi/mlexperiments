# %%
# DataFrame
import pandas as pd

# Matplot
import matplotlib.pyplot as plt
# %matplotlib inline

# Scikit-learn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.manifold import TSNE
from sklearn.feature_extraction.text import TfidfVectorizer

# Keras
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential, Model
from keras.layers import Input, Activation, Dense, Dropout, Embedding, Flatten, Conv1D, MaxPooling1D, LSTM, concatenate
from keras.layers import GaussianDropout, GaussianNoise
from keras.layers import GRU, Bidirectional, TimeDistributed
from keras import utils
from keras.callbacks import ReduceLROnPlateau, EarlyStopping

# nltk
import nltk
from nltk.corpus import stopwords
from  nltk.stem import SnowballStemmer

# Word2vec
import gensim

# Utility
import os
import re
import numpy as np
from collections import Counter
import logging
import time
import pickle
import itertools

# Set log
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
# Out:
# Using TensorFlow backend.

# %%
# DATASET
DATASET_COLUMNS = ["target", "text"]
DATASET_ENCODING = "ISO-8859-1"
TRAIN_SIZE = 0.8

# TEXT CLENAING
TEXT_CLEANING_RE = "@\S+|https?:\S+|http?:\S"

# WORD2VEC
W2V_WINDOW = 7
W2V_EPOCH = 32
W2V_MIN_COUNT = 6
W2V_SIZE = 100

SEQUENCE_LENGTH = 200

MAXLEN = 100
MAX_SENTENCES = 15
MAX_WORDS = 20000
EMBEDDING_DIM = 100
VALIDATION_SPLIT = 0.2

# EXPORT
KERAS_MODEL = "model.h5"
WORD2VEC_MODEL = "model.w2v"
TOKENIZER_MODEL = "tokenizer.pkl"
ENCODER_MODEL = "encoder.pkl"

# %%
from keras import backend as K
from keras.engine.topology import Layer, InputSpec
from keras import initializers

# class defining the custom attention layer
class HierarchicalAttentionNetwork(Layer):
    def __init__(self, attention_dim):
        self.init = initializers.get('normal')
        self.supports_masking = True
        self.attention_dim = attention_dim
        super(HierarchicalAttentionNetwork, self).__init__()

    def build(self, input_shape):
        assert len(input_shape) == 3
        self.W = K.variable(self.init((input_shape[-1], self.attention_dim)))
        self.b = K.variable(self.init((self.attention_dim,)))
        self.u = K.variable(self.init((self.attention_dim, 1)))
        self.trainable_weights = [self.W, self.b, self.u]
        super(HierarchicalAttentionNetwork, self).build(input_shape)

    def compute_mask(self, inputs, mask=None):
        return None

    def call(self, x, mask=None):
        # size of x :[batch_size, sel_len, attention_dim]
        # size of u :[batch_size, attention_dim]
        # uit = tanh(xW+b)
        uit = K.tanh(K.bias_add(K.dot(x, self.W), self.b))

        ait = K.exp(K.squeeze(K.dot(uit, self.u), -1))

        if mask is not None:
            # Cast the mask to floatX to avoid float64 upcasting
            ait *= K.cast(mask, K.floatx())
        ait /= K.cast(K.sum(ait, axis=1, keepdims=True) + K.epsilon(), K.floatx())
        weighted_input = x * K.expand_dims(ait)
        output = K.sum(weighted_input, axis=1)

        return output

    def compute_output_shape(self, input_shape):
        return input_shape[0], input_shape[-1]

# %%
df_train = pd.read_csv("yelp2015/train.csv", encoding=DATASET_ENCODING , names=DATASET_COLUMNS)
df_test = pd.read_csv("yelp2015/test.csv", encoding=DATASET_ENCODING , names=DATASET_COLUMNS)

# %%
def preprocess(text):
    # Remove link,user and special characters
    text = re.sub(TEXT_CLEANING_RE, ' ', str(text).lower()).strip()
    tokens = []
    for token in text.split():
      tokens.append(token)
    return " ".join(tokens)

# %%
# %%time
df_train.text = df_train.text.apply(lambda x: preprocess(x))
df_test.text = df_test.text.apply(lambda x: preprocess(x))
# Out:
# Wall time: 19.5 s

# %%
decode_map = {1: 0, 2: 1, 3: 2, 4: 3, 5: 4}
def decode_sentiment(label):
    return decode_map[int(label)]

# %%
# %%time
df_train.target = df_train.target.apply(lambda x: decode_sentiment(x))
df_test.target = df_test.target.apply(lambda x: decode_sentiment(x))
# Out:
# Wall time: 415 ms

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\covin\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# %%time
documents = [_text.split() for _text in df_train.text]
# Out:
# Wall time: 10.2 s

# %%
w2v_model = gensim.models.word2vec.Word2Vec(size=W2V_SIZE, 
                                            window=W2V_WINDOW, 
                                            min_count=W2V_MIN_COUNT, 
                                            workers=8)

# %%
w2v_model.build_vocab(documents)
# Out:
# 2020-05-03 09:28:21,573 : INFO : collecting all words and their counts
# 2020-05-03 09:28:21,574 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2020-05-03 09:28:21,861 : INFO : PROGRESS: at sentence #10000, processed 1301608 words, keeping 73325 word types
# 2020-05-03 09:28:22,123 : INFO : PROGRESS: at sentence #20000, processed 2581717 words, keeping 119474 word types
# 2020-05-03 09:28:22,389 : INFO : PROGRESS: at sentence #30000, processed 3869673 words, keeping 157572 word types
# 2020-05-03 09:28:22,642 : INFO : PROGRESS: at sentence #40000, processed 5133261 words, keeping 188307 word types
# 2020-05-03 09:28:22,905 : INFO : PROGRESS: at sentence #50000, processed 6392410 words, keeping 217321 word types
# 2020-05-03 09:28:23,143 : INFO : PROGRESS: at sentence #60000, processed 7635534 words, keeping 242870 word types
# 2020-05-03 09:28:23,401 : INFO : PROGRESS: at sentence #70000, processed 8936557 words, keeping 272165 word types
# 2020-05-03 09:28:23,655 : INFO : PROGRESS: at sentence #80000, processed 10245606 words, keeping 299296 word types
# 2020-05-03 09:28:23,898 : INFO : PROGRESS: at sentence #90000, processed 11472479 words, keeping 324553 word types
# 2020-05-03 09:28:24,148 : INFO : PROGRESS: at sentence #100000, processed 12741926 words, keeping 349495 word types
# 2020-05-03 09:28:24,432 : INFO : PROGRESS: at sentence #110000, processed 14070562 words, keeping 375232 word types
# 2020-05-03 09:28:24,684 : INFO : PROGRESS: at sentence #120000, processed 15300524 words, keeping 397679 word types
# 2020-05-03 09:28:24,954 : INFO : PROGRESS: at sentence #130000, processed 16710537 words, keeping 425741 word types
# 2020-05-03 09:28:25,263 : INFO : PROGRESS: at sentence #140000, processed 18129503 words, keeping 452407 word types
# 2020-05-03 09:28:25,522 : INFO : PROGRESS: at sentence #150000, processed 19436742 words, keeping 474671 word types
# 2020-05-03 09:28:25,794 : INFO : PROGRESS: at sentence #160000, processed 20832116 words, keeping 499623 word types
# 2020-05-03 09:28:26,109 : INFO : PROGRESS: at sentence #170000, processed 22447545 words, keeping 529109 word types
# 2020-05-03 09:28:26,414 : INFO : PROGRESS: at sentence #180000, processed 23989072 words, keeping 556932 word types
# 2020-05-03 09:28:26,700 : INFO : PROGRESS: at sentence #190000, processed 25406421 words, keeping 581662 word types
# 2020-05-03 09:28:27,006 : INFO : PROGRESS: at sentence #200000, processed 26789882 words, keeping 604857 word types
# 2020-05-03 09:28:27,270 : INFO : PROGRESS: at sentence #210000, processed 28107941 words, keeping 626508 word types
# 2020-05-03 09:28:27,548 : INFO : PROGRESS: at sentence #220000, processed 29500749 words, keeping 648288 word types
# 2020-05-03 09:28:27,818 : INFO : PROGRESS: at sentence #230000, processed 30865193 words, keeping 670383 word types
# 2020-05-03 09:28:28,101 : INFO : PROGRESS: at sentence #240000, processed 32233598 words, keeping 692189 word types
# 2020-05-03 09:28:28,383 : INFO : PROGRESS: at sentence #250000, processed 33465362 words, keeping 710208 word types
# 2020-05-03 09:28:28,645 : INFO : PROGRESS: at sentence #260000, processed 34752000 words, keeping 728703 word types
# 2020-05-03 09:28:28,902 : INFO : PROGRESS: at sentence #270000, processed 36049648 words, keeping 747401 word types
# 2020-05-03 09:28:29,189 : INFO : PROGRESS: at sentence #280000, processed 37424135 words, keeping 768302 word types
# 2020-05-03 09:28:29,452 : INFO : PROGRESS: at sentence #290000, processed 38716464 words, keeping 787859 word types
# 2020-05-03 09:28:29,725 : INFO : PROGRESS: at sentence #300000, processed 40056239 words, keeping 807957 word types
# 2020-05-03 09:28:29,997 : INFO : PROGRESS: at sentence #310000, processed 41436533 words, keeping 827948 word types
# 2020-05-03 09:28:30,277 : INFO : PROGRESS: at sentence #320000, processed 42807541 words, keeping 848251 word types
# 2020-05-03 09:28:30,584 : INFO : PROGRESS: at sentence #330000, processed 44172682 words, keeping 867996 word types
# 2020-05-03 09:28:30,845 : INFO : PROGRESS: at sentence #340000, processed 45379612 words, keeping 901469 word types
# 2020-05-03 09:28:31,118 : INFO : PROGRESS: at sentence #350000, processed 46711844 words, keeping 920418 word types
# 2020-05-03 09:28:31,398 : INFO : PROGRESS: at sentence #360000, processed 48102105 words, keeping 943406 word types
# 2020-05-03 09:28:31,669 : INFO : PROGRESS: at sentence #370000, processed 49421122 words, keeping 961598 word types
# 2020-05-03 09:28:31,966 : INFO : PROGRESS: at sentence #380000, processed 50897422 words, keeping 982756 word types
# 2020-05-03 09:28:32,236 : INFO : PROGRESS: at sentence #390000, processed 52220739 words, keeping 999693 word types
# 2020-05-03 09:28:32,539 : INFO : PROGRESS: at sentence #400000, processed 53603024 words, keeping 1018514 word types
# 2020-05-03 09:28:32,829 : INFO : PROGRESS: at sentence #410000, processed 54929982 words, keeping 1036581 word types
# 2020-05-03 09:28:33,108 : INFO : PROGRESS: at sentence #420000, processed 56236730 words, keeping 1053988 word types
# 2020-05-03 09:28:33,407 : INFO : PROGRESS: at sentence #430000, processed 57579689 words, keeping 1071684 word types
# 2020-05-03 09:28:33,705 : INFO : PROGRESS: at sentence #440000, processed 58913040 words, keeping 1087945 word types
# 2020-05-03 09:28:34,002 : INFO : PROGRESS: at sentence #450000, processed 60261545 words, keeping 1104605 word types
# 2020-05-03 09:28:34,287 : INFO : PROGRESS: at sentence #460000, processed 61694700 words, keeping 1124622 word types
# 2020-05-03 09:28:34,606 : INFO : PROGRESS: at sentence #470000, processed 63027040 words, keeping 1153259 word types
# 2020-05-03 09:28:34,878 : INFO : PROGRESS: at sentence #480000, processed 64371224 words, keeping 1171305 word types
# 2020-05-03 09:28:35,151 : INFO : PROGRESS: at sentence #490000, processed 65724740 words, keeping 1188850 word types
# 2020-05-03 09:28:35,455 : INFO : PROGRESS: at sentence #500000, processed 67146561 words, keeping 1209030 word types
# 2020-05-03 09:28:35,746 : INFO : PROGRESS: at sentence #510000, processed 68474079 words, keeping 1225383 word types
# 2020-05-03 09:28:36,025 : INFO : PROGRESS: at sentence #520000, processed 69805674 words, keeping 1241553 word types
# 2020-05-03 09:28:36,294 : INFO : PROGRESS: at sentence #530000, processed 71127836 words, keeping 1257958 word types
# 2020-05-03 09:28:36,576 : INFO : PROGRESS: at sentence #540000, processed 72469591 words, keeping 1273869 word types
# 2020-05-03 09:28:36,862 : INFO : PROGRESS: at sentence #550000, processed 73787564 words, keeping 1290022 word types
# 2020-05-03 09:28:37,137 : INFO : PROGRESS: at sentence #560000, processed 75138815 words, keeping 1305927 word types
# 2020-05-03 09:28:37,411 : INFO : PROGRESS: at sentence #570000, processed 76463741 words, keeping 1321428 word types
# 2020-05-03 09:28:37,721 : INFO : PROGRESS: at sentence #580000, processed 77822793 words, keeping 1338061 word types
# 2020-05-03 09:28:37,991 : INFO : PROGRESS: at sentence #590000, processed 79173825 words, keeping 1353380 word types
# 2020-05-03 09:28:38,277 : INFO : PROGRESS: at sentence #600000, processed 80570302 words, keeping 1369738 word types
# 2020-05-03 09:28:38,550 : INFO : PROGRESS: at sentence #610000, processed 81860353 words, keeping 1384552 word types
# 2020-05-03 09:28:38,902 : INFO : PROGRESS: at sentence #620000, processed 83153544 words, keeping 1401828 word types
# 2020-05-03 09:28:39,173 : INFO : PROGRESS: at sentence #630000, processed 84496553 words, keeping 1415848 word types
# 2020-05-03 09:28:39,440 : INFO : PROGRESS: at sentence #640000, processed 85802715 words, keeping 1429671 word types
# 2020-05-03 09:28:39,707 : INFO : collected 1444447 word types from a corpus of 87161194 raw words and 650000 sentences
# 2020-05-03 09:28:39,708 : INFO : Loading a fresh vocabulary
# 2020-05-03 09:28:41,890 : INFO : effective_min_count=6 retains 152070 unique words (10% of original 1444447, drops 1292377)
# 2020-05-03 09:28:41,890 : INFO : effective_min_count=6 leaves 85422479 word corpus (98% of original 87161194, drops 1738715)
# 2020-05-03 09:28:42,421 : INFO : deleting the raw counts dictionary of 1444447 items
# 2020-05-03 09:28:42,458 : INFO : sample=0.001 downsamples 48 most-common words
# 2020-05-03 09:28:42,458 : INFO : downsampling leaves estimated 64954863 word corpus (76.0% of prior 85422479)
# 2020-05-03 09:28:43,009 : INFO : estimated required memory for 152070 words and 100 dimensions: 197691000 bytes
# 2020-05-03 09:28:43,010 : INFO : resetting layer weights

# %%
words = w2v_model.wv.vocab.keys()
vocab_size = len(words)
print("Vocab size", vocab_size)
# Out:
# Vocab size 152070

# %%
# %%time
w2v_model.train(documents, total_examples=len(documents), epochs=W2V_EPOCH)
# Out:
# 2020-05-03 09:29:12,348 : INFO : training model with 8 workers on 152070 vocabulary and 100 features, using sg=0 hs=0 sample=0.001 negative=5 window=7
# 2020-05-03 09:29:13,361 : INFO : EPOCH 1 - PROGRESS: at 2.27% examples, 1391887 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:29:14,370 : INFO : EPOCH 1 - PROGRESS: at 4.56% examples, 1411473 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:29:15,380 : INFO : EPOCH 1 - PROGRESS: at 6.89% examples, 1413038 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:29:16,391 : INFO : EPOCH 1 - PROGRESS: at 9.31% examples, 1421456 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:29:17,398 : INFO : EPOCH 1 - PROGRESS: at 11.59% examples, 1429233 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:29:18,411 : INFO : EPOCH 1 - PROGRESS: at 13.96% examples, 1426166 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:29:19,415 : INFO : EPOCH 1 - PROGRESS: at 16.28% examples, 1427750 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:29:20,431 : INFO : EPOCH 1 - PROGRESS: at 18.66% examples, 1429698 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:29:21,439 : INFO : EPOCH 1 - PROGRESS: at 20.74% examples, 1428074 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:29:22,439 : INFO : EPOCH 1 - PROGRESS: at 22.99% examples, 1431088 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:29:23,450 : INFO : EPOCH 1 - PROGRESS: at 25.09% examples, 1433370 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:29:24,465 : INFO : EPOCH 1 - PROGRESS: at 26.90% examples, 1432292 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:29:25,469 : INFO : EPOCH 1 - PROGRESS: at 28.99% examples, 1430051 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:29:26,483 : INFO : EPOCH 1 - PROGRESS: at 31.14% examples, 1428277 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:29:27,487 : INFO : EPOCH 1 - PROGRESS: at 33.27% examples, 1426887 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:29:28,488 : INFO : EPOCH 1 - PROGRESS: at 35.50% examples, 1428536 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:29:29,503 : INFO : EPOCH 1 - PROGRESS: at 37.75% examples, 1428644 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:29:30,508 : INFO : EPOCH 1 - PROGRESS: at 40.09% examples, 1428730 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:29:31,523 : INFO : EPOCH 1 - PROGRESS: at 42.29% examples, 1428276 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:29:32,527 : INFO : EPOCH 1 - PROGRESS: at 44.60% examples, 1428442 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:29:33,535 : INFO : EPOCH 1 - PROGRESS: at 46.78% examples, 1428517 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:29:34,535 : INFO : EPOCH 1 - PROGRESS: at 48.95% examples, 1428087 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:29:35,548 : INFO : EPOCH 1 - PROGRESS: at 51.16% examples, 1428081 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:29:36,553 : INFO : EPOCH 1 - PROGRESS: at 53.46% examples, 1427822 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:29:37,556 : INFO : EPOCH 1 - PROGRESS: at 55.47% examples, 1423953 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:29:38,562 : INFO : EPOCH 1 - PROGRESS: at 57.72% examples, 1425505 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:29:39,568 : INFO : EPOCH 1 - PROGRESS: at 59.88% examples, 1426267 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:29:40,569 : INFO : EPOCH 1 - PROGRESS: at 62.02% examples, 1426027 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:29:41,580 : INFO : EPOCH 1 - PROGRESS: at 64.27% examples, 1426038 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:29:42,596 : INFO : EPOCH 1 - PROGRESS: at 66.58% examples, 1426508 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:29:43,606 : INFO : EPOCH 1 - PROGRESS: at 68.80% examples, 1427161 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:29:44,615 : INFO : EPOCH 1 - PROGRESS: at 70.84% examples, 1426019 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:29:45,619 : INFO : EPOCH 1 - PROGRESS: at 73.05% examples, 1426147 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:29:46,620 : INFO : EPOCH 1 - PROGRESS: at 75.25% examples, 1425927 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:29:47,631 : INFO : EPOCH 1 - PROGRESS: at 77.39% examples, 1426116 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:29:48,637 : INFO : EPOCH 1 - PROGRESS: at 79.61% examples, 1426417 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:29:49,639 : INFO : EPOCH 1 - PROGRESS: at 81.84% examples, 1426541 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:29:50,639 : INFO : EPOCH 1 - PROGRESS: at 84.14% examples, 1427567 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:29:51,642 : INFO : EPOCH 1 - PROGRESS: at 86.32% examples, 1427693 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:29:52,642 : INFO : EPOCH 1 - PROGRESS: at 88.49% examples, 1427553 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:29:53,652 : INFO : EPOCH 1 - PROGRESS: at 90.64% examples, 1426533 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:29:54,657 : INFO : EPOCH 1 - PROGRESS: at 92.81% examples, 1426630 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:29:55,676 : INFO : EPOCH 1 - PROGRESS: at 95.14% examples, 1427107 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:29:56,680 : INFO : EPOCH 1 - PROGRESS: at 97.39% examples, 1427556 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:29:57,682 : INFO : EPOCH 1 - PROGRESS: at 99.61% examples, 1427443 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:29:57,822 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-05-03 09:29:57,831 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-05-03 09:29:57,835 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-05-03 09:29:57,840 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-05-03 09:29:57,845 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-05-03 09:29:57,848 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-05-03 09:29:57,849 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-05-03 09:29:57,852 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-05-03 09:29:57,854 : INFO : EPOCH - 1 : training on 87161194 raw words (64960091 effective words) took 45.5s, 1427741 effective words/s
# 2020-05-03 09:29:58,867 : INFO : EPOCH 2 - PROGRESS: at 2.34% examples, 1437233 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:29:59,874 : INFO : EPOCH 2 - PROGRESS: at 4.66% examples, 1443402 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:30:00,874 : INFO : EPOCH 2 - PROGRESS: at 6.95% examples, 1429154 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:30:01,882 : INFO : EPOCH 2 - PROGRESS: at 9.27% examples, 1420581 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:30:02,890 : INFO : EPOCH 2 - PROGRESS: at 11.58% examples, 1430703 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:30:03,900 : INFO : EPOCH 2 - PROGRESS: at 14.00% examples, 1434193 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:30:04,908 : INFO : EPOCH 2 - PROGRESS: at 16.34% examples, 1434804 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:30:05,912 : INFO : EPOCH 2 - PROGRESS: at 18.70% examples, 1437023 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:30:06,920 : INFO : EPOCH 2 - PROGRESS: at 20.80% examples, 1435341 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:30:07,923 : INFO : EPOCH 2 - PROGRESS: at 23.03% examples, 1437136 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:30:08,943 : INFO : EPOCH 2 - PROGRESS: at 25.14% examples, 1437819 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:30:09,954 : INFO : EPOCH 2 - PROGRESS: at 26.96% examples, 1436697 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:30:10,956 : INFO : EPOCH 2 - PROGRESS: at 28.94% examples, 1429314 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:30:11,957 : INFO : EPOCH 2 - PROGRESS: at 30.86% examples, 1418910 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:30:12,967 : INFO : EPOCH 2 - PROGRESS: at 32.99% examples, 1415698 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:30:13,972 : INFO : EPOCH 2 - PROGRESS: at 35.21% examples, 1418708 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:30:14,973 : INFO : EPOCH 2 - PROGRESS: at 37.40% examples, 1419134 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:30:15,978 : INFO : EPOCH 2 - PROGRESS: at 39.76% examples, 1419500 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:30:16,981 : INFO : EPOCH 2 - PROGRESS: at 41.97% examples, 1420761 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:30:17,983 : INFO : EPOCH 2 - PROGRESS: at 44.27% examples, 1422140 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:30:18,984 : INFO : EPOCH 2 - PROGRESS: at 46.52% examples, 1423012 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:30:19,984 : INFO : EPOCH 2 - PROGRESS: at 48.72% examples, 1424154 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:30:20,996 : INFO : EPOCH 2 - PROGRESS: at 50.79% examples, 1422026 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:30:22,010 : INFO : EPOCH 2 - PROGRESS: at 53.09% examples, 1420608 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:30:23,021 : INFO : EPOCH 2 - PROGRESS: at 55.25% examples, 1420460 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:30:24,028 : INFO : EPOCH 2 - PROGRESS: at 57.54% examples, 1421734 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:30:25,039 : INFO : EPOCH 2 - PROGRESS: at 59.68% examples, 1422898 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:30:26,061 : INFO : EPOCH 2 - PROGRESS: at 61.86% examples, 1422757 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:30:27,070 : INFO : EPOCH 2 - PROGRESS: at 64.13% examples, 1423461 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:30:28,073 : INFO : EPOCH 2 - PROGRESS: at 66.42% examples, 1424411 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:30:29,076 : INFO : EPOCH 2 - PROGRESS: at 68.67% examples, 1425889 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:30:30,078 : INFO : EPOCH 2 - PROGRESS: at 70.78% examples, 1426239 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:30:31,079 : INFO : EPOCH 2 - PROGRESS: at 72.93% examples, 1425650 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:30:32,089 : INFO : EPOCH 2 - PROGRESS: at 75.16% examples, 1425532 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:30:33,094 : INFO : EPOCH 2 - PROGRESS: at 77.34% examples, 1426753 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:30:34,094 : INFO : EPOCH 2 - PROGRESS: at 79.51% examples, 1426250 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:30:35,099 : INFO : EPOCH 2 - PROGRESS: at 81.70% examples, 1425659 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:30:36,100 : INFO : EPOCH 2 - PROGRESS: at 83.93% examples, 1425895 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:30:37,120 : INFO : EPOCH 2 - PROGRESS: at 86.21% examples, 1426597 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:30:38,126 : INFO : EPOCH 2 - PROGRESS: at 88.44% examples, 1427403 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:30:39,140 : INFO : EPOCH 2 - PROGRESS: at 90.65% examples, 1427115 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:30:40,148 : INFO : EPOCH 2 - PROGRESS: at 92.86% examples, 1427642 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:30:41,148 : INFO : EPOCH 2 - PROGRESS: at 95.09% examples, 1427369 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:30:42,152 : INFO : EPOCH 2 - PROGRESS: at 97.37% examples, 1428140 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:30:43,153 : INFO : EPOCH 2 - PROGRESS: at 99.56% examples, 1427558 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:30:43,328 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-05-03 09:30:43,331 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-05-03 09:30:43,332 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-05-03 09:30:43,333 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-05-03 09:30:43,335 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-05-03 09:30:43,336 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-05-03 09:30:43,349 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-05-03 09:30:43,351 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-05-03 09:30:43,353 : INFO : EPOCH - 2 : training on 87161194 raw words (64955846 effective words) took 45.5s, 1427788 effective words/s
# 2020-05-03 09:30:44,362 : INFO : EPOCH 3 - PROGRESS: at 2.30% examples, 1415045 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:30:45,368 : INFO : EPOCH 3 - PROGRESS: at 4.62% examples, 1436535 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:30:46,375 : INFO : EPOCH 3 - PROGRESS: at 7.03% examples, 1445594 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:30:47,378 : INFO : EPOCH 3 - PROGRESS: at 9.45% examples, 1451040 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:30:48,380 : INFO : EPOCH 3 - PROGRESS: at 11.70% examples, 1449473 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:30:49,382 : INFO : EPOCH 3 - PROGRESS: at 14.09% examples, 1448385 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:30:50,390 : INFO : EPOCH 3 - PROGRESS: at 16.39% examples, 1444784 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:30:51,395 : INFO : EPOCH 3 - PROGRESS: at 18.76% examples, 1445664 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:30:52,397 : INFO : EPOCH 3 - PROGRESS: at 20.95% examples, 1449696 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:30:53,404 : INFO : EPOCH 3 - PROGRESS: at 23.14% examples, 1446503 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:30:54,409 : INFO : EPOCH 3 - PROGRESS: at 25.22% examples, 1448133 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:30:55,426 : INFO : EPOCH 3 - PROGRESS: at 27.07% examples, 1446129 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:30:56,431 : INFO : EPOCH 3 - PROGRESS: at 29.21% examples, 1446041 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:30:57,442 : INFO : EPOCH 3 - PROGRESS: at 31.47% examples, 1447157 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:30:58,449 : INFO : EPOCH 3 - PROGRESS: at 33.67% examples, 1446549 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:30:59,451 : INFO : EPOCH 3 - PROGRESS: at 35.86% examples, 1446919 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:31:00,460 : INFO : EPOCH 3 - PROGRESS: at 38.05% examples, 1442626 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:31:01,461 : INFO : EPOCH 3 - PROGRESS: at 40.35% examples, 1441444 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:31:02,463 : INFO : EPOCH 3 - PROGRESS: at 42.47% examples, 1438507 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:31:03,473 : INFO : EPOCH 3 - PROGRESS: at 44.78% examples, 1438129 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:31:04,490 : INFO : EPOCH 3 - PROGRESS: at 46.99% examples, 1437362 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:31:05,490 : INFO : EPOCH 3 - PROGRESS: at 49.14% examples, 1437172 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:31:06,492 : INFO : EPOCH 3 - PROGRESS: at 51.36% examples, 1436901 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:31:07,499 : INFO : EPOCH 3 - PROGRESS: at 53.57% examples, 1433910 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:31:08,500 : INFO : EPOCH 3 - PROGRESS: at 55.68% examples, 1432644 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:31:09,501 : INFO : EPOCH 3 - PROGRESS: at 57.84% examples, 1433141 words/s, in_qsize 16, out_qsize 2
# 2020-05-03 09:31:10,504 : INFO : EPOCH 3 - PROGRESS: at 60.05% examples, 1433507 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:31:11,506 : INFO : EPOCH 3 - PROGRESS: at 62.26% examples, 1434263 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:31:12,507 : INFO : EPOCH 3 - PROGRESS: at 64.47% examples, 1433692 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:31:13,521 : INFO : EPOCH 3 - PROGRESS: at 66.80% examples, 1434071 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:31:14,531 : INFO : EPOCH 3 - PROGRESS: at 68.95% examples, 1433400 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:31:15,535 : INFO : EPOCH 3 - PROGRESS: at 71.04% examples, 1433219 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:31:16,538 : INFO : EPOCH 3 - PROGRESS: at 73.29% examples, 1433911 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:31:17,547 : INFO : EPOCH 3 - PROGRESS: at 75.46% examples, 1433292 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:31:18,558 : INFO : EPOCH 3 - PROGRESS: at 77.62% examples, 1433242 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:31:19,561 : INFO : EPOCH 3 - PROGRESS: at 79.80% examples, 1432487 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:31:20,571 : INFO : EPOCH 3 - PROGRESS: at 82.07% examples, 1432717 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:31:21,575 : INFO : EPOCH 3 - PROGRESS: at 84.27% examples, 1432270 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:31:22,581 : INFO : EPOCH 3 - PROGRESS: at 86.49% examples, 1432381 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:31:23,590 : INFO : EPOCH 3 - PROGRESS: at 88.69% examples, 1432174 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:31:24,600 : INFO : EPOCH 3 - PROGRESS: at 90.92% examples, 1432473 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:31:25,606 : INFO : EPOCH 3 - PROGRESS: at 93.06% examples, 1431839 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:31:26,609 : INFO : EPOCH 3 - PROGRESS: at 95.27% examples, 1430845 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:31:27,625 : INFO : EPOCH 3 - PROGRESS: at 97.54% examples, 1431481 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:31:28,626 : INFO : EPOCH 3 - PROGRESS: at 99.81% examples, 1431829 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:31:28,700 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-05-03 09:31:28,705 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-05-03 09:31:28,707 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-05-03 09:31:28,712 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-05-03 09:31:28,713 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-05-03 09:31:28,714 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-05-03 09:31:28,724 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-05-03 09:31:28,725 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-05-03 09:31:28,725 : INFO : EPOCH - 3 : training on 87161194 raw words (64950114 effective words) took 45.4s, 1431633 effective words/s
# 2020-05-03 09:31:29,748 : INFO : EPOCH 4 - PROGRESS: at 2.31% examples, 1403217 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:31:30,749 : INFO : EPOCH 4 - PROGRESS: at 4.59% examples, 1418488 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:31:31,751 : INFO : EPOCH 4 - PROGRESS: at 6.93% examples, 1421813 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:31:32,752 : INFO : EPOCH 4 - PROGRESS: at 9.32% examples, 1427774 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:31:33,753 : INFO : EPOCH 4 - PROGRESS: at 11.63% examples, 1439990 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:31:34,768 : INFO : EPOCH 4 - PROGRESS: at 14.00% examples, 1434649 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:31:35,781 : INFO : EPOCH 4 - PROGRESS: at 16.34% examples, 1435144 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:31:36,783 : INFO : EPOCH 4 - PROGRESS: at 18.67% examples, 1434255 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:31:37,783 : INFO : EPOCH 4 - PROGRESS: at 20.75% examples, 1433139 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:31:38,789 : INFO : EPOCH 4 - PROGRESS: at 22.98% examples, 1433255 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:31:39,794 : INFO : EPOCH 4 - PROGRESS: at 25.07% examples, 1436182 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:31:40,803 : INFO : EPOCH 4 - PROGRESS: at 26.89% examples, 1435478 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:31:41,811 : INFO : EPOCH 4 - PROGRESS: at 29.02% examples, 1434795 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:31:42,816 : INFO : EPOCH 4 - PROGRESS: at 31.19% examples, 1434694 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:31:43,827 : INFO : EPOCH 4 - PROGRESS: at 33.39% examples, 1434726 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:31:44,828 : INFO : EPOCH 4 - PROGRESS: at 35.61% examples, 1435913 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:31:45,843 : INFO : EPOCH 4 - PROGRESS: at 37.87% examples, 1435192 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:31:46,857 : INFO : EPOCH 4 - PROGRESS: at 40.26% examples, 1436616 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:31:47,866 : INFO : EPOCH 4 - PROGRESS: at 42.47% examples, 1436166 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:31:48,877 : INFO : EPOCH 4 - PROGRESS: at 44.82% examples, 1436883 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:31:49,887 : INFO : EPOCH 4 - PROGRESS: at 47.07% examples, 1438068 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:31:50,901 : INFO : EPOCH 4 - PROGRESS: at 49.27% examples, 1438721 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:31:51,913 : INFO : EPOCH 4 - PROGRESS: at 51.48% examples, 1437145 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:31:52,918 : INFO : EPOCH 4 - PROGRESS: at 53.73% examples, 1435084 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:31:53,921 : INFO : EPOCH 4 - PROGRESS: at 55.94% examples, 1435990 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:31:54,929 : INFO : EPOCH 4 - PROGRESS: at 58.07% examples, 1436749 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:31:55,934 : INFO : EPOCH 4 - PROGRESS: at 60.31% examples, 1437580 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:31:56,933 : INFO : EPOCH 4 - PROGRESS: at 62.18% examples, 1429939 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:31:57,936 : INFO : EPOCH 4 - PROGRESS: at 64.11% examples, 1423202 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:31:58,944 : INFO : EPOCH 4 - PROGRESS: at 66.01% examples, 1416335 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:31:59,958 : INFO : EPOCH 4 - PROGRESS: at 68.09% examples, 1413318 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:32:00,967 : INFO : EPOCH 4 - PROGRESS: at 70.20% examples, 1413088 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:32:01,978 : INFO : EPOCH 4 - PROGRESS: at 72.39% examples, 1413537 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:32:02,982 : INFO : EPOCH 4 - PROGRESS: at 74.57% examples, 1413788 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:32:03,997 : INFO : EPOCH 4 - PROGRESS: at 76.72% examples, 1414364 words/s, in_qsize 16, out_qsize 1
# 2020-05-03 09:32:05,004 : INFO : EPOCH 4 - PROGRESS: at 78.95% examples, 1414695 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:32:06,004 : INFO : EPOCH 4 - PROGRESS: at 81.17% examples, 1415186 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:32:07,008 : INFO : EPOCH 4 - PROGRESS: at 83.40% examples, 1415992 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:32:08,013 : INFO : EPOCH 4 - PROGRESS: at 85.66% examples, 1416892 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:32:09,024 : INFO : EPOCH 4 - PROGRESS: at 87.85% examples, 1417029 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:32:10,037 : INFO : EPOCH 4 - PROGRESS: at 90.15% examples, 1418309 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:32:11,050 : INFO : EPOCH 4 - PROGRESS: at 92.35% examples, 1419017 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:32:12,051 : INFO : EPOCH 4 - PROGRESS: at 94.68% examples, 1419843 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:32:13,059 : INFO : EPOCH 4 - PROGRESS: at 96.90% examples, 1420098 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:32:14,066 : INFO : EPOCH 4 - PROGRESS: at 99.16% examples, 1420610 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:32:14,422 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-05-03 09:32:14,427 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-05-03 09:32:14,428 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-05-03 09:32:14,429 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-05-03 09:32:14,434 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-05-03 09:32:14,435 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-05-03 09:32:14,443 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-05-03 09:32:14,444 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-05-03 09:32:14,444 : INFO : EPOCH - 4 : training on 87161194 raw words (64952987 effective words) took 45.7s, 1420836 effective words/s
# 2020-05-03 09:32:15,450 : INFO : EPOCH 5 - PROGRESS: at 2.32% examples, 1436469 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:32:16,464 : INFO : EPOCH 5 - PROGRESS: at 4.61% examples, 1428988 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:32:17,470 : INFO : EPOCH 5 - PROGRESS: at 7.03% examples, 1443371 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:32:18,478 : INFO : EPOCH 5 - PROGRESS: at 9.42% examples, 1442055 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:32:19,485 : INFO : EPOCH 5 - PROGRESS: at 11.70% examples, 1445035 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:32:20,489 : INFO : EPOCH 5 - PROGRESS: at 14.09% examples, 1443936 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:32:21,489 : INFO : EPOCH 5 - PROGRESS: at 16.36% examples, 1439339 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:32:22,491 : INFO : EPOCH 5 - PROGRESS: at 18.70% examples, 1439054 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:32:23,503 : INFO : EPOCH 5 - PROGRESS: at 20.73% examples, 1431459 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:32:24,507 : INFO : EPOCH 5 - PROGRESS: at 22.88% examples, 1427801 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:32:25,518 : INFO : EPOCH 5 - PROGRESS: at 24.96% examples, 1427127 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:32:26,524 : INFO : EPOCH 5 - PROGRESS: at 26.78% examples, 1429394 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:32:27,524 : INFO : EPOCH 5 - PROGRESS: at 28.92% examples, 1430527 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:32:28,533 : INFO : EPOCH 5 - PROGRESS: at 31.11% examples, 1430725 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:32:29,541 : INFO : EPOCH 5 - PROGRESS: at 33.30% examples, 1431724 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:32:30,544 : INFO : EPOCH 5 - PROGRESS: at 35.49% examples, 1431046 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:32:31,551 : INFO : EPOCH 5 - PROGRESS: at 37.73% examples, 1431317 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:32:32,553 : INFO : EPOCH 5 - PROGRESS: at 40.03% examples, 1430289 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:32:33,557 : INFO : EPOCH 5 - PROGRESS: at 42.23% examples, 1430502 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:32:34,558 : INFO : EPOCH 5 - PROGRESS: at 44.49% examples, 1429242 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:32:35,571 : INFO : EPOCH 5 - PROGRESS: at 46.72% examples, 1429583 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:32:36,579 : INFO : EPOCH 5 - PROGRESS: at 48.96% examples, 1431287 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:32:37,579 : INFO : EPOCH 5 - PROGRESS: at 51.11% examples, 1430321 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:32:38,597 : INFO : EPOCH 5 - PROGRESS: at 53.41% examples, 1429195 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:32:39,603 : INFO : EPOCH 5 - PROGRESS: at 55.59% examples, 1429547 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:32:40,618 : INFO : EPOCH 5 - PROGRESS: at 57.78% examples, 1429764 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:32:41,630 : INFO : EPOCH 5 - PROGRESS: at 59.96% examples, 1429558 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:32:42,633 : INFO : EPOCH 5 - PROGRESS: at 62.14% examples, 1429819 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:32:43,636 : INFO : EPOCH 5 - PROGRESS: at 64.41% examples, 1430596 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:32:44,640 : INFO : EPOCH 5 - PROGRESS: at 66.68% examples, 1430549 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:32:45,650 : INFO : EPOCH 5 - PROGRESS: at 68.91% examples, 1431444 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:32:46,654 : INFO : EPOCH 5 - PROGRESS: at 71.02% examples, 1431533 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:32:47,665 : INFO : EPOCH 5 - PROGRESS: at 73.22% examples, 1431274 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:32:48,669 : INFO : EPOCH 5 - PROGRESS: at 75.39% examples, 1430569 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:32:49,676 : INFO : EPOCH 5 - PROGRESS: at 77.57% examples, 1431374 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:32:50,687 : INFO : EPOCH 5 - PROGRESS: at 79.82% examples, 1431575 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:32:51,691 : INFO : EPOCH 5 - PROGRESS: at 82.00% examples, 1430438 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:32:52,692 : INFO : EPOCH 5 - PROGRESS: at 84.20% examples, 1429838 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:32:53,694 : INFO : EPOCH 5 - PROGRESS: at 86.35% examples, 1429539 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:32:54,709 : INFO : EPOCH 5 - PROGRESS: at 88.54% examples, 1428995 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:32:55,722 : INFO : EPOCH 5 - PROGRESS: at 90.79% examples, 1429476 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:32:56,734 : INFO : EPOCH 5 - PROGRESS: at 93.01% examples, 1429779 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:32:57,737 : INFO : EPOCH 5 - PROGRESS: at 95.26% examples, 1429577 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:32:58,743 : INFO : EPOCH 5 - PROGRESS: at 97.46% examples, 1429511 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:32:59,755 : INFO : EPOCH 5 - PROGRESS: at 99.71% examples, 1429416 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:32:59,857 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-05-03 09:32:59,869 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-05-03 09:32:59,872 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-05-03 09:32:59,877 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-05-03 09:32:59,880 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-05-03 09:32:59,881 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-05-03 09:32:59,882 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-05-03 09:32:59,888 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-05-03 09:32:59,889 : INFO : EPOCH - 5 : training on 87161194 raw words (64953330 effective words) took 45.4s, 1429435 effective words/s
# 2020-05-03 09:33:00,893 : INFO : EPOCH 6 - PROGRESS: at 2.31% examples, 1429277 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:33:01,907 : INFO : EPOCH 6 - PROGRESS: at 4.47% examples, 1389047 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:33:02,926 : INFO : EPOCH 6 - PROGRESS: at 6.45% examples, 1319209 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:33:03,938 : INFO : EPOCH 6 - PROGRESS: at 8.58% examples, 1305136 words/s, in_qsize 16, out_qsize 1
# 2020-05-03 09:33:04,939 : INFO : EPOCH 6 - PROGRESS: at 10.66% examples, 1308621 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:33:05,944 : INFO : EPOCH 6 - PROGRESS: at 12.85% examples, 1318819 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:33:06,946 : INFO : EPOCH 6 - PROGRESS: at 15.27% examples, 1337134 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:33:07,951 : INFO : EPOCH 6 - PROGRESS: at 17.53% examples, 1349465 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:33:08,953 : INFO : EPOCH 6 - PROGRESS: at 19.74% examples, 1356195 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:33:09,966 : INFO : EPOCH 6 - PROGRESS: at 21.91% examples, 1366253 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:33:10,973 : INFO : EPOCH 6 - PROGRESS: at 24.16% examples, 1375074 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:33:11,986 : INFO : EPOCH 6 - PROGRESS: at 26.13% examples, 1380477 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:33:12,992 : INFO : EPOCH 6 - PROGRESS: at 28.09% examples, 1385485 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:33:13,993 : INFO : EPOCH 6 - PROGRESS: at 30.24% examples, 1388615 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:33:15,014 : INFO : EPOCH 6 - PROGRESS: at 32.45% examples, 1390429 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:33:16,015 : INFO : EPOCH 6 - PROGRESS: at 34.60% examples, 1393979 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:33:17,017 : INFO : EPOCH 6 - PROGRESS: at 36.78% examples, 1395982 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:33:18,027 : INFO : EPOCH 6 - PROGRESS: at 39.18% examples, 1398139 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:33:19,037 : INFO : EPOCH 6 - PROGRESS: at 41.50% examples, 1400455 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:33:20,049 : INFO : EPOCH 6 - PROGRESS: at 43.77% examples, 1404250 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:33:21,059 : INFO : EPOCH 6 - PROGRESS: at 46.06% examples, 1406426 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:33:22,066 : INFO : EPOCH 6 - PROGRESS: at 48.27% examples, 1407876 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:33:23,067 : INFO : EPOCH 6 - PROGRESS: at 50.40% examples, 1408961 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:33:24,068 : INFO : EPOCH 6 - PROGRESS: at 52.73% examples, 1409538 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:33:25,072 : INFO : EPOCH 6 - PROGRESS: at 54.80% examples, 1407362 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:33:26,076 : INFO : EPOCH 6 - PROGRESS: at 56.97% examples, 1407310 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:33:27,079 : INFO : EPOCH 6 - PROGRESS: at 59.00% examples, 1407003 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:33:28,081 : INFO : EPOCH 6 - PROGRESS: at 61.19% examples, 1408151 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:33:29,086 : INFO : EPOCH 6 - PROGRESS: at 63.44% examples, 1408856 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:33:30,092 : INFO : EPOCH 6 - PROGRESS: at 65.73% examples, 1411112 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:33:31,092 : INFO : EPOCH 6 - PROGRESS: at 67.96% examples, 1412132 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:33:32,107 : INFO : EPOCH 6 - PROGRESS: at 70.12% examples, 1412620 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:33:33,108 : INFO : EPOCH 6 - PROGRESS: at 72.30% examples, 1413324 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:33:34,109 : INFO : EPOCH 6 - PROGRESS: at 74.54% examples, 1414777 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:33:35,116 : INFO : EPOCH 6 - PROGRESS: at 76.68% examples, 1415460 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:33:36,124 : INFO : EPOCH 6 - PROGRESS: at 78.90% examples, 1415714 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:33:37,133 : INFO : EPOCH 6 - PROGRESS: at 81.16% examples, 1416425 words/s, in_qsize 15, out_qsize 2
# 2020-05-03 09:33:38,137 : INFO : EPOCH 6 - PROGRESS: at 83.39% examples, 1417218 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:33:39,147 : INFO : EPOCH 6 - PROGRESS: at 85.67% examples, 1418333 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:33:40,159 : INFO : EPOCH 6 - PROGRESS: at 87.94% examples, 1419482 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:33:41,163 : INFO : EPOCH 6 - PROGRESS: at 90.16% examples, 1420114 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:33:42,163 : INFO : EPOCH 6 - PROGRESS: at 92.34% examples, 1420652 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:33:43,168 : INFO : EPOCH 6 - PROGRESS: at 94.56% examples, 1419756 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:33:44,178 : INFO : EPOCH 6 - PROGRESS: at 96.77% examples, 1419799 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:33:45,198 : INFO : EPOCH 6 - PROGRESS: at 99.06% examples, 1420291 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:33:45,601 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-05-03 09:33:45,606 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-05-03 09:33:45,607 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-05-03 09:33:45,608 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-05-03 09:33:45,619 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-05-03 09:33:45,620 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-05-03 09:33:45,625 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-05-03 09:33:45,626 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-05-03 09:33:45,626 : INFO : EPOCH - 6 : training on 87161194 raw words (64958979 effective words) took 45.7s, 1420421 effective words/s
# 2020-05-03 09:33:46,638 : INFO : EPOCH 7 - PROGRESS: at 2.33% examples, 1431853 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:33:47,654 : INFO : EPOCH 7 - PROGRESS: at 4.66% examples, 1436396 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:33:48,664 : INFO : EPOCH 7 - PROGRESS: at 7.07% examples, 1447408 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:33:49,666 : INFO : EPOCH 7 - PROGRESS: at 9.50% examples, 1450280 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:33:50,678 : INFO : EPOCH 7 - PROGRESS: at 11.75% examples, 1447839 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:33:51,681 : INFO : EPOCH 7 - PROGRESS: at 14.14% examples, 1446161 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:33:52,684 : INFO : EPOCH 7 - PROGRESS: at 16.46% examples, 1446046 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:33:53,696 : INFO : EPOCH 7 - PROGRESS: at 18.81% examples, 1445601 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:33:54,699 : INFO : EPOCH 7 - PROGRESS: at 21.00% examples, 1448330 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:33:55,703 : INFO : EPOCH 7 - PROGRESS: at 23.25% examples, 1449721 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:33:56,713 : INFO : EPOCH 7 - PROGRESS: at 25.30% examples, 1449564 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:33:57,727 : INFO : EPOCH 7 - PROGRESS: at 27.14% examples, 1447488 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:33:58,728 : INFO : EPOCH 7 - PROGRESS: at 29.31% examples, 1448798 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:33:59,731 : INFO : EPOCH 7 - PROGRESS: at 31.48% examples, 1446331 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:34:00,741 : INFO : EPOCH 7 - PROGRESS: at 33.68% examples, 1445179 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:34:01,742 : INFO : EPOCH 7 - PROGRESS: at 35.85% examples, 1444772 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:34:02,745 : INFO : EPOCH 7 - PROGRESS: at 38.13% examples, 1444216 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:34:03,763 : INFO : EPOCH 7 - PROGRESS: at 40.54% examples, 1445498 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:34:04,771 : INFO : EPOCH 7 - PROGRESS: at 42.81% examples, 1446699 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:34:05,786 : INFO : EPOCH 7 - PROGRESS: at 45.11% examples, 1446488 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:34:06,789 : INFO : EPOCH 7 - PROGRESS: at 47.32% examples, 1446401 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:34:07,798 : INFO : EPOCH 7 - PROGRESS: at 49.51% examples, 1446598 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:34:08,815 : INFO : EPOCH 7 - PROGRESS: at 51.79% examples, 1444700 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:34:09,825 : INFO : EPOCH 7 - PROGRESS: at 54.05% examples, 1443310 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:34:10,835 : INFO : EPOCH 7 - PROGRESS: at 56.24% examples, 1443098 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:34:11,838 : INFO : EPOCH 7 - PROGRESS: at 58.32% examples, 1442806 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:34:12,848 : INFO : EPOCH 7 - PROGRESS: at 60.59% examples, 1443864 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:34:13,851 : INFO : EPOCH 7 - PROGRESS: at 62.82% examples, 1443173 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:34:14,867 : INFO : EPOCH 7 - PROGRESS: at 65.08% examples, 1442836 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:34:15,869 : INFO : EPOCH 7 - PROGRESS: at 67.31% examples, 1442751 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:34:16,879 : INFO : EPOCH 7 - PROGRESS: at 69.53% examples, 1442774 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:34:17,879 : INFO : EPOCH 7 - PROGRESS: at 71.69% examples, 1443190 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:34:18,880 : INFO : EPOCH 7 - PROGRESS: at 73.91% examples, 1443149 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:34:19,887 : INFO : EPOCH 7 - PROGRESS: at 76.07% examples, 1443884 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:34:20,902 : INFO : EPOCH 7 - PROGRESS: at 78.32% examples, 1443417 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:34:21,904 : INFO : EPOCH 7 - PROGRESS: at 80.56% examples, 1443426 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:34:22,905 : INFO : EPOCH 7 - PROGRESS: at 82.78% examples, 1443071 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:34:23,915 : INFO : EPOCH 7 - PROGRESS: at 84.99% examples, 1442717 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:34:24,933 : INFO : EPOCH 7 - PROGRESS: at 87.31% examples, 1442828 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:34:25,951 : INFO : EPOCH 7 - PROGRESS: at 89.53% examples, 1442975 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:34:26,958 : INFO : EPOCH 7 - PROGRESS: at 91.78% examples, 1443472 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:34:27,963 : INFO : EPOCH 7 - PROGRESS: at 94.01% examples, 1443219 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:34:28,978 : INFO : EPOCH 7 - PROGRESS: at 96.30% examples, 1443093 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:34:29,990 : INFO : EPOCH 7 - PROGRESS: at 98.59% examples, 1443287 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:34:30,588 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-05-03 09:34:30,597 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-05-03 09:34:30,598 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-05-03 09:34:30,599 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-05-03 09:34:30,612 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-05-03 09:34:30,613 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-05-03 09:34:30,613 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-05-03 09:34:30,615 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-05-03 09:34:30,615 : INFO : EPOCH - 7 : training on 87161194 raw words (64954678 effective words) took 45.0s, 1443913 effective words/s
# 2020-05-03 09:34:31,628 : INFO : EPOCH 8 - PROGRESS: at 2.39% examples, 1467281 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:34:32,634 : INFO : EPOCH 8 - PROGRESS: at 4.72% examples, 1462704 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:34:33,635 : INFO : EPOCH 8 - PROGRESS: at 7.07% examples, 1456371 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:34:34,651 : INFO : EPOCH 8 - PROGRESS: at 9.53% examples, 1457674 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:34:35,654 : INFO : EPOCH 8 - PROGRESS: at 11.80% examples, 1456367 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:34:36,658 : INFO : EPOCH 8 - PROGRESS: at 14.21% examples, 1456578 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:34:37,665 : INFO : EPOCH 8 - PROGRESS: at 16.31% examples, 1433571 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:34:38,674 : INFO : EPOCH 8 - PROGRESS: at 18.66% examples, 1432380 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:34:39,675 : INFO : EPOCH 8 - PROGRESS: at 20.78% examples, 1434664 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:34:40,676 : INFO : EPOCH 8 - PROGRESS: at 23.05% examples, 1439041 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:34:41,688 : INFO : EPOCH 8 - PROGRESS: at 25.12% examples, 1438501 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:34:42,691 : INFO : EPOCH 8 - PROGRESS: at 26.94% examples, 1438399 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:34:43,705 : INFO : EPOCH 8 - PROGRESS: at 29.07% examples, 1437253 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:34:44,714 : INFO : EPOCH 8 - PROGRESS: at 31.32% examples, 1439745 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:34:45,714 : INFO : EPOCH 8 - PROGRESS: at 33.55% examples, 1441778 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:34:46,733 : INFO : EPOCH 8 - PROGRESS: at 35.78% examples, 1441439 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:34:47,735 : INFO : EPOCH 8 - PROGRESS: at 38.05% examples, 1441405 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:34:48,744 : INFO : EPOCH 8 - PROGRESS: at 40.42% examples, 1442050 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:34:49,750 : INFO : EPOCH 8 - PROGRESS: at 42.68% examples, 1443177 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:34:50,764 : INFO : EPOCH 8 - PROGRESS: at 44.98% examples, 1441850 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:34:51,766 : INFO : EPOCH 8 - PROGRESS: at 47.14% examples, 1441248 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:34:52,768 : INFO : EPOCH 8 - PROGRESS: at 49.33% examples, 1441816 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:34:53,787 : INFO : EPOCH 8 - PROGRESS: at 51.53% examples, 1439081 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:34:54,793 : INFO : EPOCH 8 - PROGRESS: at 53.82% examples, 1438508 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:34:55,794 : INFO : EPOCH 8 - PROGRESS: at 56.02% examples, 1439282 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:34:56,798 : INFO : EPOCH 8 - PROGRESS: at 58.13% examples, 1439375 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:34:57,810 : INFO : EPOCH 8 - PROGRESS: at 60.34% examples, 1438842 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:34:58,828 : INFO : EPOCH 8 - PROGRESS: at 62.61% examples, 1439351 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:34:59,839 : INFO : EPOCH 8 - PROGRESS: at 64.90% examples, 1439412 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:35:00,840 : INFO : EPOCH 8 - PROGRESS: at 67.14% examples, 1440202 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:35:01,856 : INFO : EPOCH 8 - PROGRESS: at 69.42% examples, 1440742 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:35:02,858 : INFO : EPOCH 8 - PROGRESS: at 71.53% examples, 1440632 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:35:03,870 : INFO : EPOCH 8 - PROGRESS: at 73.73% examples, 1439645 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:35:04,870 : INFO : EPOCH 8 - PROGRESS: at 75.93% examples, 1440323 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:35:05,880 : INFO : EPOCH 8 - PROGRESS: at 78.08% examples, 1439716 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:35:06,883 : INFO : EPOCH 8 - PROGRESS: at 80.32% examples, 1439393 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:35:07,887 : INFO : EPOCH 8 - PROGRESS: at 82.54% examples, 1439378 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:35:08,896 : INFO : EPOCH 8 - PROGRESS: at 84.77% examples, 1439372 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:35:09,906 : INFO : EPOCH 8 - PROGRESS: at 87.09% examples, 1439740 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:35:10,913 : INFO : EPOCH 8 - PROGRESS: at 89.29% examples, 1439984 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:35:11,920 : INFO : EPOCH 8 - PROGRESS: at 91.56% examples, 1440543 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:35:12,927 : INFO : EPOCH 8 - PROGRESS: at 93.76% examples, 1440433 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:35:13,928 : INFO : EPOCH 8 - PROGRESS: at 96.02% examples, 1440127 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:35:14,932 : INFO : EPOCH 8 - PROGRESS: at 98.26% examples, 1440136 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:35:15,676 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-05-03 09:35:15,680 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-05-03 09:35:15,682 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-05-03 09:35:15,683 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-05-03 09:35:15,685 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-05-03 09:35:15,699 : INFO : worker thread finished; awaiting finish of 2 more threads
# ...
# 2020-05-03 09:51:36,024 : INFO : EPOCH 30 - PROGRESS: at 50.99% examples, 1425652 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:51:37,032 : INFO : EPOCH 30 - PROGRESS: at 53.19% examples, 1422051 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:51:38,038 : INFO : EPOCH 30 - PROGRESS: at 55.30% examples, 1420923 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:51:39,050 : INFO : EPOCH 30 - PROGRESS: at 57.54% examples, 1420865 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:51:40,055 : INFO : EPOCH 30 - PROGRESS: at 59.67% examples, 1422342 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:51:41,065 : INFO : EPOCH 30 - PROGRESS: at 61.87% examples, 1423037 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:51:42,067 : INFO : EPOCH 30 - PROGRESS: at 64.11% examples, 1423415 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:51:43,067 : INFO : EPOCH 30 - PROGRESS: at 66.35% examples, 1423452 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:51:44,085 : INFO : EPOCH 30 - PROGRESS: at 68.58% examples, 1423832 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:51:45,086 : INFO : EPOCH 30 - PROGRESS: at 70.68% examples, 1424046 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:51:46,091 : INFO : EPOCH 30 - PROGRESS: at 72.83% examples, 1423397 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:51:47,092 : INFO : EPOCH 30 - PROGRESS: at 75.05% examples, 1423462 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:51:48,095 : INFO : EPOCH 30 - PROGRESS: at 77.16% examples, 1423604 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:51:49,100 : INFO : EPOCH 30 - PROGRESS: at 79.37% examples, 1423769 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:51:50,111 : INFO : EPOCH 30 - PROGRESS: at 81.60% examples, 1423627 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:51:51,119 : INFO : EPOCH 30 - PROGRESS: at 83.80% examples, 1423273 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:51:52,139 : INFO : EPOCH 30 - PROGRESS: at 86.00% examples, 1422704 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:51:53,146 : INFO : EPOCH 30 - PROGRESS: at 88.17% examples, 1422440 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:51:54,153 : INFO : EPOCH 30 - PROGRESS: at 90.37% examples, 1422572 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:51:55,168 : INFO : EPOCH 30 - PROGRESS: at 92.56% examples, 1422605 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:51:56,179 : INFO : EPOCH 30 - PROGRESS: at 94.83% examples, 1422429 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:51:57,200 : INFO : EPOCH 30 - PROGRESS: at 97.07% examples, 1422390 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:51:58,213 : INFO : EPOCH 30 - PROGRESS: at 99.33% examples, 1422549 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:51:58,490 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-05-03 09:51:58,495 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-05-03 09:51:58,505 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-05-03 09:51:58,510 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-05-03 09:51:58,512 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-05-03 09:51:58,514 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-05-03 09:51:58,515 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-05-03 09:51:58,522 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-05-03 09:51:58,523 : INFO : EPOCH - 30 : training on 87161194 raw words (64957271 effective words) took 45.7s, 1422623 effective words/s
# 2020-05-03 09:51:59,532 : INFO : EPOCH 31 - PROGRESS: at 2.20% examples, 1349250 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:52:00,541 : INFO : EPOCH 31 - PROGRESS: at 4.39% examples, 1363980 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:52:01,541 : INFO : EPOCH 31 - PROGRESS: at 6.65% examples, 1369081 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:52:02,551 : INFO : EPOCH 31 - PROGRESS: at 9.00% examples, 1381465 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:52:03,551 : INFO : EPOCH 31 - PROGRESS: at 11.31% examples, 1400523 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:52:04,559 : INFO : EPOCH 31 - PROGRESS: at 13.67% examples, 1401306 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:52:05,560 : INFO : EPOCH 31 - PROGRESS: at 15.99% examples, 1407042 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:52:06,566 : INFO : EPOCH 31 - PROGRESS: at 18.31% examples, 1409387 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:52:07,572 : INFO : EPOCH 31 - PROGRESS: at 20.43% examples, 1411058 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:52:08,576 : INFO : EPOCH 31 - PROGRESS: at 22.62% examples, 1413625 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:52:09,586 : INFO : EPOCH 31 - PROGRESS: at 24.78% examples, 1416139 words/s, in_qsize 16, out_qsize 1
# 2020-05-03 09:52:10,604 : INFO : EPOCH 31 - PROGRESS: at 26.55% examples, 1414745 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:52:11,617 : INFO : EPOCH 31 - PROGRESS: at 28.64% examples, 1414980 words/s, in_qsize 16, out_qsize 0
# 2020-05-03 09:52:12,620 : INFO : EPOCH 31 - PROGRESS: at 30.75% examples, 1414419 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:52:13,638 : INFO : EPOCH 31 - PROGRESS: at 32.99% examples, 1415558 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:52:14,642 : INFO : EPOCH 31 - PROGRESS: at 35.17% examples, 1416417 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:52:15,653 : INFO : EPOCH 31 - PROGRESS: at 37.34% examples, 1415617 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:52:16,659 : INFO : EPOCH 31 - PROGRESS: at 39.67% examples, 1415264 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:52:17,668 : INFO : EPOCH 31 - PROGRESS: at 41.85% examples, 1414351 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:52:18,677 : INFO : EPOCH 31 - PROGRESS: at 44.05% examples, 1414032 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:52:19,680 : INFO : EPOCH 31 - PROGRESS: at 46.31% examples, 1414860 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:52:20,686 : INFO : EPOCH 31 - PROGRESS: at 48.50% examples, 1415994 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:52:21,700 : INFO : EPOCH 31 - PROGRESS: at 50.64% examples, 1416013 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:52:22,702 : INFO : EPOCH 31 - PROGRESS: at 52.93% examples, 1414941 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:52:23,704 : INFO : EPOCH 31 - PROGRESS: at 55.10% examples, 1415330 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:52:24,716 : INFO : EPOCH 31 - PROGRESS: at 57.35% examples, 1416166 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:52:25,732 : INFO : EPOCH 31 - PROGRESS: at 59.44% examples, 1416178 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:52:26,733 : INFO : EPOCH 31 - PROGRESS: at 61.57% examples, 1416029 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:52:27,738 : INFO : EPOCH 31 - PROGRESS: at 63.82% examples, 1416201 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:52:28,742 : INFO : EPOCH 31 - PROGRESS: at 66.01% examples, 1416388 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:52:29,756 : INFO : EPOCH 31 - PROGRESS: at 68.27% examples, 1417113 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:52:30,762 : INFO : EPOCH 31 - PROGRESS: at 70.39% examples, 1417553 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:52:31,765 : INFO : EPOCH 31 - PROGRESS: at 72.55% examples, 1417337 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:52:32,766 : INFO : EPOCH 31 - PROGRESS: at 74.78% examples, 1418242 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:52:33,768 : INFO : EPOCH 31 - PROGRESS: at 76.87% examples, 1418035 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:52:34,777 : INFO : EPOCH 31 - PROGRESS: at 79.10% examples, 1418344 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:52:35,785 : INFO : EPOCH 31 - PROGRESS: at 81.32% examples, 1418271 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:52:36,800 : INFO : EPOCH 31 - PROGRESS: at 83.58% examples, 1419116 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:52:37,806 : INFO : EPOCH 31 - PROGRESS: at 85.80% examples, 1419429 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:52:38,813 : INFO : EPOCH 31 - PROGRESS: at 87.97% examples, 1419061 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:52:39,813 : INFO : EPOCH 31 - PROGRESS: at 90.11% examples, 1418418 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:52:40,817 : INFO : EPOCH 31 - PROGRESS: at 92.27% examples, 1418904 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:52:41,826 : INFO : EPOCH 31 - PROGRESS: at 94.53% examples, 1418575 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:52:42,834 : INFO : EPOCH 31 - PROGRESS: at 96.70% examples, 1418065 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:52:43,835 : INFO : EPOCH 31 - PROGRESS: at 98.96% examples, 1418676 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:52:44,276 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-05-03 09:52:44,289 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-05-03 09:52:44,291 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-05-03 09:52:44,298 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-05-03 09:52:44,299 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-05-03 09:52:44,301 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-05-03 09:52:44,303 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-05-03 09:52:44,308 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-05-03 09:52:44,309 : INFO : EPOCH - 31 : training on 87161194 raw words (64956813 effective words) took 45.8s, 1418859 effective words/s
# 2020-05-03 09:52:45,326 : INFO : EPOCH 32 - PROGRESS: at 2.33% examples, 1424247 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:52:46,339 : INFO : EPOCH 32 - PROGRESS: at 4.66% examples, 1435890 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:52:47,346 : INFO : EPOCH 32 - PROGRESS: at 7.00% examples, 1430917 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:52:48,363 : INFO : EPOCH 32 - PROGRESS: at 9.42% examples, 1434590 words/s, in_qsize 16, out_qsize 3
# 2020-05-03 09:52:49,375 : INFO : EPOCH 32 - PROGRESS: at 11.67% examples, 1433696 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:52:50,375 : INFO : EPOCH 32 - PROGRESS: at 14.02% examples, 1431434 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:52:51,384 : INFO : EPOCH 32 - PROGRESS: at 16.35% examples, 1432378 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:52:52,386 : INFO : EPOCH 32 - PROGRESS: at 18.69% examples, 1432665 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:52:53,388 : INFO : EPOCH 32 - PROGRESS: at 20.81% examples, 1433312 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:52:54,388 : INFO : EPOCH 32 - PROGRESS: at 23.02% examples, 1434175 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:52:55,392 : INFO : EPOCH 32 - PROGRESS: at 25.03% examples, 1431326 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:52:56,403 : INFO : EPOCH 32 - PROGRESS: at 26.82% examples, 1430055 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:52:57,417 : INFO : EPOCH 32 - PROGRESS: at 28.94% examples, 1428648 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:52:58,420 : INFO : EPOCH 32 - PROGRESS: at 31.12% examples, 1429157 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:52:59,421 : INFO : EPOCH 32 - PROGRESS: at 33.24% examples, 1426893 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:53:00,426 : INFO : EPOCH 32 - PROGRESS: at 35.42% examples, 1426986 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:53:01,438 : INFO : EPOCH 32 - PROGRESS: at 37.68% examples, 1427787 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:53:02,449 : INFO : EPOCH 32 - PROGRESS: at 40.02% examples, 1427563 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:53:03,451 : INFO : EPOCH 32 - PROGRESS: at 42.20% examples, 1427683 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:53:04,458 : INFO : EPOCH 32 - PROGRESS: at 44.49% examples, 1426859 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:53:05,479 : INFO : EPOCH 32 - PROGRESS: at 46.70% examples, 1426177 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:53:06,491 : INFO : EPOCH 32 - PROGRESS: at 48.91% examples, 1426800 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:53:07,507 : INFO : EPOCH 32 - PROGRESS: at 51.08% examples, 1425987 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:53:08,514 : INFO : EPOCH 32 - PROGRESS: at 53.40% examples, 1425968 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:53:09,520 : INFO : EPOCH 32 - PROGRESS: at 55.52% examples, 1425314 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:53:10,535 : INFO : EPOCH 32 - PROGRESS: at 57.75% examples, 1426015 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:53:11,541 : INFO : EPOCH 32 - PROGRESS: at 59.92% examples, 1426419 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:53:12,546 : INFO : EPOCH 32 - PROGRESS: at 62.09% examples, 1426508 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:53:13,550 : INFO : EPOCH 32 - PROGRESS: at 64.34% examples, 1426832 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:53:14,554 : INFO : EPOCH 32 - PROGRESS: at 66.56% examples, 1426181 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:53:15,569 : INFO : EPOCH 32 - PROGRESS: at 68.77% examples, 1426046 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:53:16,570 : INFO : EPOCH 32 - PROGRESS: at 70.82% examples, 1425515 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:53:17,582 : INFO : EPOCH 32 - PROGRESS: at 73.01% examples, 1424927 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:53:18,590 : INFO : EPOCH 32 - PROGRESS: at 75.23% examples, 1424881 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:53:19,591 : INFO : EPOCH 32 - PROGRESS: at 77.34% examples, 1425085 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:53:20,593 : INFO : EPOCH 32 - PROGRESS: at 79.54% examples, 1425158 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:53:21,601 : INFO : EPOCH 32 - PROGRESS: at 81.78% examples, 1425253 words/s, in_qsize 13, out_qsize 2
# 2020-05-03 09:53:22,605 : INFO : EPOCH 32 - PROGRESS: at 84.06% examples, 1426000 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:53:23,614 : INFO : EPOCH 32 - PROGRESS: at 86.25% examples, 1425949 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:53:24,620 : INFO : EPOCH 32 - PROGRESS: at 88.43% examples, 1425833 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:53:25,621 : INFO : EPOCH 32 - PROGRESS: at 90.56% examples, 1424809 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:53:26,623 : INFO : EPOCH 32 - PROGRESS: at 92.64% examples, 1423661 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:53:27,623 : INFO : EPOCH 32 - PROGRESS: at 94.87% examples, 1423147 words/s, in_qsize 15, out_qsize 0
# 2020-05-03 09:53:28,631 : INFO : EPOCH 32 - PROGRESS: at 97.09% examples, 1423190 words/s, in_qsize 14, out_qsize 1
# 2020-05-03 09:53:29,645 : INFO : EPOCH 32 - PROGRESS: at 99.33% examples, 1423111 words/s, in_qsize 12, out_qsize 3
# 2020-05-03 09:53:29,932 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-05-03 09:53:29,936 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-05-03 09:53:29,937 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-05-03 09:53:29,938 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-05-03 09:53:29,939 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-05-03 09:53:29,954 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-05-03 09:53:29,957 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-05-03 09:53:29,958 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-05-03 09:53:29,959 : INFO : EPOCH - 32 : training on 87161194 raw words (64955879 effective words) took 45.6s, 1423051 effective words/s
# 2020-05-03 09:53:29,959 : INFO : training on a 2789158208 raw words (2078567380 effective words) took 1457.6s, 1426016 effective words/s
# Wall time: 24min 17s
# (2078567380, 2789158208)

# %%
from nltk import tokenize

reviews = []
labels = []
texts = []

for idx, _ in df_train.iterrows():
    text = df_train.text[idx]
    texts.append(text)
    sentences = tokenize.sent_tokenize(text)
    reviews.append(sentences)
    labels.append(df_train.target[idx])

TRAIN_SIZE = len(texts)

for idx, _ in df_test.iterrows():
    text = df_test.text[idx]
    texts.append(text)
    sentences = tokenize.sent_tokenize(text)
    reviews.append(sentences)
    labels.append(df_test.target[idx])

# %%
from keras.preprocessing.text import text_to_word_sequence

tokenizer = Tokenizer()
tokenizer.fit_on_texts(texts)

data = np.zeros((len(texts), MAX_SENTENCES, MAXLEN), dtype='int32')

for i, sentences in enumerate(reviews):
    for j, sent in enumerate(sentences):
        if j < MAX_SENTENCES:
            wordTokens = text_to_word_sequence(sent)
            k = 0
            for _, word in enumerate(wordTokens):
                if k < MAXLEN and tokenizer.word_index[word] < MAX_WORDS:
                    data[i, j, k] = tokenizer.word_index[word]
                    k = k + 1

word_index = tokenizer.word_index
print('Total %s unique tokens.' % len(word_index))
# Out:
# Total 274081 unique tokens.

# %%
from keras.utils.np_utils import to_categorical

labels = to_categorical(np.asarray(labels))
print('Shape of reviews (data) tensor:', data.shape)
print('Shape of sentiment (label) tensor:', labels.shape)
# Out:
# Shape of reviews (data) tensor: (700000, 15, 100)
# Shape of sentiment (label) tensor: (700000, 5)

# %%
x_train = data[:TRAIN_SIZE]
y_train = labels[:TRAIN_SIZE]
x_test = data[TRAIN_SIZE:]
y_test = labels[TRAIN_SIZE:]

# %%
# building Hierachical Attention network
embedding_matrix = np.random.random((len(word_index) + 1, EMBEDDING_DIM))
for word, i in tokenizer.word_index.items():
  if word in w2v_model.wv:
    embedding_matrix[i] = w2v_model.wv[word]

embedding_layer = Embedding(len(word_index) + 1, EMBEDDING_DIM, weights=[embedding_matrix],
                            input_length=MAXLEN, trainable=True)

# %%
sentence_input = Input(shape=(MAXLEN,), dtype='int32')
embedded_sequences = embedding_layer(sentence_input)
lstm_word = Bidirectional(GRU(50, return_sequences=True))(embedded_sequences)
attn_word = HierarchicalAttentionNetwork(100)(lstm_word)
sentenceEncoder = Model(sentence_input, attn_word)

review_input = Input(shape=(MAX_SENTENCES, MAXLEN), dtype='int32')
review_encoder = TimeDistributed(sentenceEncoder)(review_input)
lstm_sentence = Bidirectional(GRU(50, return_sequences=True))(review_encoder)
attn_sentence = HierarchicalAttentionNetwork(100)(lstm_sentence)
preds = Dense(5, activation='softmax')(attn_sentence)
model = Model(review_input, preds)
# Out:
# tracking <tf.Variable 'hierarchical_attention_network_3/Variable:0' shape=(100, 100) dtype=float32> W
# tracking <tf.Variable 'hierarchical_attention_network_3/Variable_1:0' shape=(100,) dtype=float32> b
# tracking <tf.Variable 'hierarchical_attention_network_3/Variable_2:0' shape=(100, 1) dtype=float32> u
# tracking <tf.Variable 'hierarchical_attention_network_4/Variable:0' shape=(100, 100) dtype=float32> W
# tracking <tf.Variable 'hierarchical_attention_network_4/Variable_1:0' shape=(100,) dtype=float32> b
# tracking <tf.Variable 'hierarchical_attention_network_4/Variable_2:0' shape=(100, 1) dtype=float32> u

# %%
from keras import optimizers
sgd = optimizers.SGD(lr=0.01, momentum=0.9, nesterov=False)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['acc'])
model.summary()
# Out:
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         (None, 15, 100)           0
# _________________________________________________________________
# time_distributed_2 (TimeDist (None, 15, 100)           27463700
# _________________________________________________________________
# bidirectional_4 (Bidirection (None, 15, 100)           45300
# _________________________________________________________________
# hierarchical_attention_netwo (None, 100)               10200
# _________________________________________________________________
# dense_2 (Dense)              (None, 5)                 505
# =================================================================
# Total params: 27,519,705
# Trainable params: 27,519,705
# Non-trainable params: 0
# _________________________________________________________________

# %%
callbacks = [EarlyStopping(monitor='val_acc', patience=5, mode='max')]

# %%
print("model fitting - Hierachical attention network")
history = model.fit(x_train, y_train, validation_split=0.2, nb_epoch=10, batch_size=64, callbacks=callbacks)
# Out:
# model fitting - Hierachical attention network
# C:\Users\covin\miniconda3\envs\tensorflow1\lib\site-packages\ipykernel_launcher.py:2: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
# Train on 520000 samples, validate on 130000 samples
# Epoch 1/10
# 520000/520000 [==============================] - 3366s 6ms/step - loss: 0.9434 - acc: 0.5846 - val_loss: 0.8022 - val_acc: 0.6547
# Epoch 2/10
# 520000/520000 [==============================] - 3390s 7ms/step - loss: 0.8554 - acc: 0.6251 - val_loss: 0.7882 - val_acc: 0.6586
# Epoch 3/10
# 520000/520000 [==============================] - 3397s 7ms/step - loss: 0.8330 - acc: 0.6346 - val_loss: 0.7841 - val_acc: 0.6603
# Epoch 4/10
# 520000/520000 [==============================] - 3420s 7ms/step - loss: 0.8185 - acc: 0.6416 - val_loss: 0.7722 - val_acc: 0.6637
# Epoch 5/10
# 520000/520000 [==============================] - 3449s 7ms/step - loss: 0.8076 - acc: 0.6458 - val_loss: 0.7760 - val_acc: 0.6654
# Epoch 6/10
# 520000/520000 [==============================] - 3451s 7ms/step - loss: 0.7987 - acc: 0.6500 - val_loss: 0.7616 - val_acc: 0.6695
# Epoch 7/10
# 520000/520000 [==============================] - 3453s 7ms/step - loss: 0.7911 - acc: 0.6531 - val_loss: 0.7641 - val_acc: 0.6688
# Epoch 8/10
# 520000/520000 [==============================] - 3458s 7ms/step - loss: 0.7846 - acc: 0.6564 - val_loss: 0.7557 - val_acc: 0.6731
# Epoch 9/10
# 520000/520000 [==============================] - 3515s 7ms/step - loss: 0.7790 - acc: 0.6583 - val_loss: 0.7548 - val_acc: 0.6725
# Epoch 10/10
# 520000/520000 [==============================] - 3552s 7ms/step - loss: 0.7736 - acc: 0.6612 - val_loss: 0.7595 - val_acc: 0.6689

# %%
# %%time
score = model.evaluate(x_test, y_test, batch_size=100)
print()
print("ACCURACY:",score[1])
print("LOSS:",score[0])
# Out:
# 50000/50000 [==============================] - 95s 2ms/step
#
# ACCURACY: 0.6438999772071838
# LOSS: 0.8079796648025512
# Wall time: 1min 35s

# %%
acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']
 
epochs = range(len(acc))
 
plt.plot(epochs, acc, 'b', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()
 
plt.figure()
 
plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
 
plt.show()

# %%
model.save("hatn_yelp2_modregex.h5")
w2v_model.save("w2v2_modregex_100.w2v")
pickle.dump(tokenizer, open("tokenizer2_modregex.pkl", "wb"), protocol=0)
# Out:
# 2020-05-03 19:39:36,722 : INFO : saving Word2Vec object under w2v2_modregex_100.w2v, separately None
# 2020-05-03 19:39:36,725 : INFO : storing np array 'vectors' to w2v2_modregex_100.w2v.wv.vectors.npy
# 2020-05-03 19:39:36,867 : INFO : not storing attribute vectors_norm
# 2020-05-03 19:39:36,868 : INFO : storing np array 'syn1neg' to w2v2_modregex_100.w2v.trainables.syn1neg.npy
# 2020-05-03 19:39:37,011 : INFO : not storing attribute cum_table
# 2020-05-03 19:39:38,952 : INFO : saved w2v2_modregex_100.w2v

# %%
from nltk import tokenize
from keras.preprocessing.text import text_to_word_sequence

def predict_new_text(text, model, tokenizer):
    text = preprocess(text)
    texts = []
    reviews = []
    texts.append(text)
    sentences = tokenize.sent_tokenize(text)
    reviews.append(sentences)

    data = np.zeros((len(texts), MAX_SENTENCES, MAXLEN), dtype='int32')

    for i, sentences in enumerate(reviews):
        for j, sent in enumerate(sentences):
            if j < MAX_SENTENCES:
                wordTokens = text_to_word_sequence(sent)
                k = 0
                for _, word in enumerate(wordTokens):
                    if k < MAXLEN and tokenizer.word_index[word] < MAX_WORDS:
                        data[i, j, k] = tokenizer.word_index[word]
                        k = k + 1
                        
    ynew = model.predict(data)
    return ynew

# %%
text = "the restaurant we went yesterday was wonderful."
print(predict_new_text(text, model, tokenizer))
labels = [1, 2, 3, 4, 5]
print(labels[np.argmax(predict_new_text(text,model, tokenizer))])
# Out:
# [[0.01285873 0.01800156 0.07911148 0.28740832 0.60261995]]
# 5

# %%
text = "the restaurant we went yesterday was awful. The food was bad, the service was bad. Horrible place, disgusting food."
print(predict_new_text(text, model, tokenizer))
labels = [1, 2, 3, 4, 5]
print(labels[np.argmax(predict_new_text(text,model, tokenizer))])
# Out:
# [[9.7188032e-01 2.6860416e-02 1.2127325e-03 3.6880778e-05 9.5644900e-06]]
# 1

# %%
text = "The movie was good, funny and entertaining. Good cast and plot."
print(predict_new_text(text, model, tokenizer))
labels = [1, 2, 3, 4, 5]
print(labels[np.argmax(predict_new_text(text,model, tokenizer))])
# Out:
# [[0.00251016 0.02307176 0.3379341  0.48427352 0.15221052]]
# 4

# %%
text = "The movie was bad, boring and too slow paced. Bad cast and plot."
print(predict_new_text(text, model, tokenizer))
labels = [1, 2, 3, 4, 5]
print(labels[np.argmax(predict_new_text(text,model, tokenizer))])
# Out:
# [[0.33235657 0.5630523  0.0964011  0.00647789 0.00171209]]
# 2

# %%
from sklearn.metrics import confusion_matrix

y_pred = model.predict(x_test)

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    # print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
conf_matrix = confusion_matrix(y_test.argmax(axis=1), y_pred.argmax(axis=1))
label_names = ['0', '1', '2', '3', '4']
plot_confusion_matrix(conf_matrix, classes=np.asarray(label_names), normalize=True,
                      title='Normalized confusion matrix')
# Out:
# Normalized confusion matrix
